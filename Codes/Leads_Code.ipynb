# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import plotly.io as pio

# %%
df = pd.read_csv('first1.csv')
df1 = pd.read_csv('second1.csv')
df2 = pd.read_csv('third1.csv')
df3_0 = pd.read_csv('platform.csv')
df3 = pd.read_csv('fourth1.csv')
df4_0 = pd.read_csv('platformAd.csv')
df4 = pd.read_csv('fifth1.csv')
df5 = pd.read_csv('sixth1.csv')
df6 = pd.read_csv('seventh1.csv')
df7 = pd.read_csv('eight1.csv')
df8_1_1 = pd.read_csv('ninth1.csv')
df9 = pd.read_csv('tenth1.csv')
df10 = pd.read_csv('eleventh1.csv')
df11 = pd.read_csv('twelve1.csv')
df12 = pd.read_csv('thirteen1.csv')
df13 = pd.read_csv('14.1.csv')

# %%
df['Year,month'] = pd.to_datetime(df['date']).dt.strftime('%Y-%m')
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['days_month'] = df['date'].dt.daysinmonth
 
df1['Year,month'] = pd.to_datetime(df1['date']).dt.strftime('%Y-%m')
df1['date'] = pd.to_datetime(df1['date'], errors='coerce')
df1['days_month'] = df1['date'].dt.daysinmonth

df2['Year,month'] = pd.to_datetime(df2['date']).dt.strftime('%Y-%m')
df2['date'] = pd.to_datetime(df2['date'], errors='coerce')
df2['days_month'] = df2['date'].dt.daysinmonth

df3_0['Year,month'] = pd.to_datetime(df3_0['date']).dt.strftime('%Y-%m')
df3_0['date'] = pd.to_datetime(df3_0['date'], errors='coerce')
df3_0['days_month'] = df3_0['date'].dt.daysinmonth

df3['Year,month'] = pd.to_datetime(df3['date']).dt.strftime('%Y-%m')
df3['date'] = pd.to_datetime(df3['date'], errors='coerce')
df3['days_month'] = df3['date'].dt.daysinmonth

df4_0['Year,month'] = pd.to_datetime(df4_0['date']).dt.strftime('%Y-%m')
df4_0['date'] = pd.to_datetime(df4_0['date'], errors='coerce')
df4_0['days_month'] = df4_0['date'].dt.daysinmonth

df4['Year,month'] = pd.to_datetime(df4['date']).dt.strftime('%Y-%m')
df4['date'] = pd.to_datetime(df4['date'], errors='coerce')
df4['days_month'] = df4['date'].dt.daysinmonth

df5['Year,month'] = pd.to_datetime(df5['date']).dt.strftime('%Y-%m')
df5['date'] = pd.to_datetime(df5['date'], errors='coerce')
df5['days_month'] = df5['date'].dt.daysinmonth

df6['Year,month'] = pd.to_datetime(df6['date']).dt.strftime('%Y-%m')
df6['date'] = pd.to_datetime(df6['date'], errors='coerce')
df6['days_month'] = df6['date'].dt.daysinmonth

df7['Year,month'] = pd.to_datetime(df7['date']).dt.strftime('%Y-%m')
df7['date'] = pd.to_datetime(df7['date'], errors='coerce')
df7['days_month'] = df7['date'].dt.daysinmonth

df8_1_1['Year,month'] = pd.to_datetime(df8_1_1['date']).dt.strftime('%Y-%m')
df8_1_1['date'] = pd.to_datetime(df8_1_1['date'], errors='coerce')
df8_1_1['days_month'] = df8_1_1['date'].dt.daysinmonth

df9['Year,month'] = pd.to_datetime(df9['date']).dt.strftime('%Y-%m')
df9['date'] = pd.to_datetime(df9['date'], errors='coerce')
df9['days_month'] = df9['date'].dt.daysinmonth

df10['Year,month'] = pd.to_datetime(df10['date']).dt.strftime('%Y-%m')
df10['date'] = pd.to_datetime(df10['date'], errors='coerce')
df10['days_month'] = df10['date'].dt.daysinmonth

df11['Year,month'] = pd.to_datetime(df11['date']).dt.strftime('%Y-%m')
df11['date'] = pd.to_datetime(df11['date'], errors='coerce')
df11['days_month'] = df11['date'].dt.daysinmonth

df12['Year,month'] = pd.to_datetime(df12['date']).dt.strftime('%Y-%m')
df12['date'] = pd.to_datetime(df12['date'], errors='coerce')
df12['days_month'] = df12['date'].dt.daysinmonth

df13['Year,month'] = pd.to_datetime(df13['date']).dt.strftime('%Y-%m')
df13['date'] = pd.to_datetime(df13['date'], errors='coerce')
df13['days_month'] = df13['date'].dt.daysinmonth

# %%
df8_1_1['reply_type']=df8_1_1['reply_type'].replace({'apply_now' : 'email','show_contact_number' : 'call'})
# df8.drop(df8.filter(regex='call/sms').columns, axis=1)
# df8.columns.str.startswith('call/sms')
# df8.loc[:,~df8.columns.str.startswith('call/sms')]

# %%
df8= df8_1_1[~df8_1_1.reply_type.str.contains("call/sms")]

# %%
df  =df.dropna()
df1 =df1.dropna()
df2 =df2.dropna()
df3 =df3.dropna()
df3_0 = df3_0.dropna()
df4 =df4.dropna()
df4_0 =df4_0.dropna()
df5 =df5.dropna()
df6 =df6.dropna()
df7 =df7.dropna()
df8 =df8.dropna()
df9 =df9.dropna()
df10 =df10.dropna()
df11 =df11.dropna()
df12 =df12.dropna()
df13=df13.dropna()

# %%
df['Avg_leads'] = (df['sumOfLeads']/df['days_month'])

# %%
new1 = df.groupby(['Year,month','platform']).agg({'Avg_leads': pd.Series.sum})
new1.to_csv('set1.csv')
plot1 = pd.read_csv('set1.csv')

# %%
fig = px.line(plot1, x="Year,month", y="Avg_leads", color="platform",color_discrete_sequence=px.colors.qualitative.Dark24,  height=600,width=900, 
              line_group="platform", hover_name="platform",title='Average Leads by monthly basis for platforms')
fig.update_traces(mode='markers+lines')
fig.show()
# pio.write_image(fig, 'first.pdf', width=700, height=775)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d7046a4a-2068-4957-93ef-dc11da9af8a0" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d7046a4a-2068-4957-93ef-dc11da9af8a0")) {
#                     Plotly.newPlot(
#                         'd7046a4a-2068-4957-93ef-dc11da9af8a0',
# ...

# %%
df1['Leads_per_ad']= (df1['sumOfLeads']/df1['ad_id'])
df1
# Out:
#            date    platform  year  ...  Year,month  days_month  Leads_per_ad
# 0    2019-01-01     Android  2019  ...     2019-01          31      6.983534
# 1    2019-01-01     Desktop  2019  ...     2019-01          31      5.261740
# 2    2019-01-01  Mobile Web  2019  ...     2019-01          31      6.491363
# 3    2019-01-01         iOS  2019  ...     2019-01          31      7.569801
# 4    2019-01-02     Android  2019  ...     2019-01          31      6.984974
# ...         ...         ...   ...  ...         ...         ...           ...
# 3277 2021-03-30         iOS  2021  ...     2021-03          31      5.768829
# 3278 2021-03-31     Android  2021  ...     2021-03          31      8.066957
# 3279 2021-03-31     Desktop  2021  ...     2021-03          31      5.485776
# 3280 2021-03-31  Mobile Web  2021  ...     2021-03          31      6.049491
# 3281 2021-03-31         iOS  2021  ...     2021-03          31      5.699677
#
# [3282 rows x 9 columns]

# %%
new2 = df1.groupby(['Year,month','platform']).agg({'Leads_per_ad': pd.Series.mean})
new2.to_csv('set2.csv')
plot2 = pd.read_csv('set2.csv')

# %%
fig = px.line(plot2, x="Year,month", y="Leads_per_ad", color="platform",color_discrete_sequence=px.colors.qualitative.Dark24,height=600,width=900, title='Leads per ad by monthly basis for platforms',
              line_group="platform", hover_name="platform")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a6578ac5-e8da-4161-a816-06c9579ab27c" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a6578ac5-e8da-4161-a816-06c9579ab27c")) {
#                     Plotly.newPlot(
#                         'a6578ac5-e8da-4161-a816-06c9579ab27c',
# ...

# %%
df2['Avg_leads'] = (df2['sumOfLeads']/df2['days_month'])
df3_0['Avg_leads'] = (df3_0['sumOfLeads']/df3_0['days_month'])

# %%
new3 = df2.groupby(['Year,month','channel_grouping']).agg({'Avg_leads': pd.Series.sum})
new3.to_csv('set3.csv')
plot3 = pd.read_csv('set3.csv')

# %%
fig = px.bar(plot3, x="Year,month", y="Avg_leads", color="channel_grouping" ,color_discrete_sequence=px.colors.qualitative.Dark24,height=600,width=900, title='Average Leads by monthly basis for channel groupings',)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="25f69285-af1f-41ff-9a3d-8873357caf53" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("25f69285-af1f-41ff-9a3d-8873357caf53")) {
#                     Plotly.newPlot(
#                         '25f69285-af1f-41ff-9a3d-8873357caf53',
# ...

# %%
df3_0.groupby(['Year,month','channel_grouping','platform']).agg({'Avg_leads': pd.Series.sum})
# Out:
#                                            Avg_leads
# Year,month channel_grouping platform
# 2019-11    (Other)          Mobile Web   1908.332411
#            Direct           Mobile Web  40102.745258
#            Display          Mobile Web     87.157840
#            Organic Search   Mobile Web  52740.642655
#            Paid Search      Mobile Web  15478.894566
# ...                                              ...
# 2021-03    Referral         Android        30.418885
#                             Desktop      5670.159467
#                             Mobile Web   7033.918028
#            Social           Desktop       453.661221
#                             Mobile Web    724.557577
#
# [349 rows x 1 columns]

# %%
match = ['Android', 'iOS']

def string_finder(row, words):
    if any(word in field for field in row for word in words):
        return 'App'
    return 'Web'

df3_0['platformAPP'] = df3_0.astype(str).apply(string_finder, words=match, axis=1)

# %%
Web = df3_0[df3_0['platformAPP']=='Web']
App = df3_0[df3_0['platformAPP']=='App']

# %%
new3_1 = Web.groupby(['Year,month','channel_grouping']).agg({'Avg_leads': pd.Series.sum})
new3_1.to_csv('set3_1.csv')
plot3_1 = pd.read_csv('set3_1.csv')

new3_2 = App.groupby(['Year,month','channel_grouping']).agg({'Avg_leads': pd.Series.sum})
new3_2.to_csv('set3_2.csv')
plot3_2 = pd.read_csv('set3_2.csv')

# %%
fig = px.bar(plot3_1, x="Year,month", y="Avg_leads", color="channel_grouping",color_discrete_sequence=px.colors.qualitative.Dark2,height=600,width=900,title='Channel Grouping by Web and Average Leads')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4d7a9864-9789-4f25-8fb1-d7f489e7c6b5" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4d7a9864-9789-4f25-8fb1-d7f489e7c6b5")) {
#                     Plotly.newPlot(
#                         '4d7a9864-9789-4f25-8fb1-d7f489e7c6b5',
# ...

# %%
fig = px.bar(plot3_2, x="Year,month", y="Avg_leads", color="channel_grouping",color_discrete_sequence=px.colors.qualitative.Dark2,height=600,width=900,title='Channel Grouping by Application and Average Leads')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cfa73d11-cef0-46cd-9e7e-2ff1148d4ce6" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cfa73d11-cef0-46cd-9e7e-2ff1148d4ce6")) {
#                     Plotly.newPlot(
#                         'cfa73d11-cef0-46cd-9e7e-2ff1148d4ce6',
# ...

# %%
df3['Leads_per_ad']= (df3['sumOfLeads']/df3['ad_id'])

# %%
new4 = df3.groupby(['Year,month','channel_grouping']).agg({'Leads_per_ad': pd.Series.mean})
new4.to_csv('set4.csv')
plot4 = pd.read_csv('set4.csv')

# %%
fig = px.bar(plot4, x="Year,month", y="Leads_per_ad", color="channel_grouping",color_discrete_sequence=px.colors.qualitative.Dark24,height=600,width=900, title='Leads per ad by monthly basis for channel grouping')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="683d055a-2250-4a59-89db-765610854bf9" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("683d055a-2250-4a59-89db-765610854bf9")) {
#                     Plotly.newPlot(
#                         '683d055a-2250-4a59-89db-765610854bf9',
# ...

# %%
df4_0['Leads_per_ad']= (df4_0['sumOfLeads']/df4_0['ad_id'])

# %%
df4_0.groupby(['Year,month','channel_grouping','platform']).agg({'Leads_per_ad': pd.Series.sum})
# Out:
#                                         Leads_per_ad
# Year,month channel_grouping platform
# 2019-11    (Other)          Mobile Web     81.577064
#            Direct           Mobile Web     92.658783
#            Display          Mobile Web     81.906617
#            Organic Search   Mobile Web     89.823625
#            Paid Search      Mobile Web    110.094581
# ...                                              ...
# 2021-03    Referral         Android       127.628269
#                             Desktop       150.493716
#                             Mobile Web    170.861908
#            Social           Desktop       145.120364
#                             Mobile Web    157.661579
#
# [349 rows x 1 columns]

# %%
match2 = ['Android', 'iOS']

def string_finder(row, words):
    if any(word in field for field in row for word in words):
        return 'App'
    return 'Web'

df4_0['platformAPP'] = df4_0.astype(str).apply(string_finder, words=match2, axis=1)
df4_0
# Out:
#             date channel_grouping  ... Leads_per_ad  platformAPP
# 1283  2019-11-17          (Other)  ...     6.353498          Web
# 1284  2019-11-17           Direct  ...     6.997521          Web
# 1285  2019-11-17          Display  ...     6.472597          Web
# 1286  2019-11-17   Organic Search  ...     6.284755          Web
# 1287  2019-11-17      Paid Search  ...     9.498796          Web
# ...          ...              ...  ...          ...          ...
# 12001 2021-03-31         Referral  ...     7.294521          App
# 12002 2021-03-31         Referral  ...     4.910030          Web
# 12003 2021-03-31         Referral  ...     5.525618          Web
# 12004 2021-03-31           Social  ...     4.726810          Web
# 12005 2021-03-31           Social  ...     5.363631          Web
#
# [9865 rows x 11 columns]

# %%
Web = df4_0[df4_0['platformAPP']=='Web']
App = df4_0[df4_0['platformAPP']=='App']

# %%
new3_3 = Web.groupby(['Year,month','channel_grouping']).agg({'Leads_per_ad': pd.Series.mean})
new3_3.to_csv('set3_3.csv')
plot3_3 = pd.read_csv('set3_3.csv')

new3_4 = App.groupby(['Year,month','channel_grouping']).agg({'Leads_per_ad': pd.Series.mean})
new3_4.to_csv('set3_4.csv')
plot3_4 = pd.read_csv('set3_4.csv')

# %%
fig = px.bar(plot3_3, x="Year,month", y="Leads_per_ad", color="channel_grouping",color_discrete_sequence=px.colors.qualitative.Safe,height=600,width=900,title='Channel Grouping by Web and Leads per Ad')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8f3b148a-596e-42bb-aa67-a76b22dfa242" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f3b148a-596e-42bb-aa67-a76b22dfa242")) {
#                     Plotly.newPlot(
#                         '8f3b148a-596e-42bb-aa67-a76b22dfa242',
# ...

# %%
fig = px.bar(plot3_4, x="Year,month", y="Leads_per_ad", color="channel_grouping",color_discrete_sequence=px.colors.qualitative.Safe,height=600,width=900,title='Channel Grouping by Application and Leads per Ad')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="22d2300f-03d0-4aa4-9949-bbbe7f436cb4" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("22d2300f-03d0-4aa4-9949-bbbe7f436cb4")) {
#                     Plotly.newPlot(
#                         '22d2300f-03d0-4aa4-9949-bbbe7f436cb4',
# ...

# %%
df4['Avg_leads'] = (df4['sumOfLeads']/df4['days_month'])

# %%
new5 = df4.groupby(['Year,month','vertical']).agg({'Avg_leads': pd.Series.sum})
new5.to_csv('set5.csv')
plot5 = pd.read_csv('set5.csv')

# %%
fig = px.line(plot5, x="Year,month", y="Avg_leads", color="vertical",color_discrete_sequence=px.colors.qualitative.Set1,height=600,width=900, title='Average leads by monthly basis for Vertical',
              line_group="vertical", hover_name="vertical")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1b69ca73-6429-496d-b628-16c86084eb0d" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b69ca73-6429-496d-b628-16c86084eb0d")) {
#                     Plotly.newPlot(
#                         '1b69ca73-6429-496d-b628-16c86084eb0d',
# ...

# %%
df5['Leads_per_ad']= (df5['sumOfLeads']/df5['ad_id'])

# %%
new6 = df5.groupby(['Year,month','vertical']).agg({'Leads_per_ad': pd.Series.mean})
new6.to_csv('set6.csv')
plot6 = pd.read_csv('set6.csv')

# %%
fig = px.line(plot6, x="Year,month", y="Leads_per_ad", color="vertical",color_discrete_sequence=px.colors.qualitative.Set1,height=600,width=900, title='Leads per ad by monthly basis for Vertical',
              line_group="vertical", hover_name="vertical")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9b3a5b7b-4e80-4f4a-a727-813dd695a54d" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9b3a5b7b-4e80-4f4a-a727-813dd695a54d")) {
#                     Plotly.newPlot(
#                         '9b3a5b7b-4e80-4f4a-a727-813dd695a54d',
# ...

# %%
df6['Avg_leads'] = (df6['sumOfLeads']/df6['days_month'])

# %%
auto = df6[df6['vertical']=='Auto']
generalist = df6[df6['vertical']=='Generalist']
jobs = df6[df6['vertical']=='Jobs']
services = df6[df6['vertical']=='Services']
property = df6[df6['vertical']=='Property']

# %%
new7_1 = auto.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_1.to_csv('set7_1.csv')
plot7_1 = pd.read_csv('set7_1.csv')

new7_2 = generalist.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_2.to_csv('set7_2.csv')
plot7_2 = pd.read_csv('set7_2.csv')

new7_3 = jobs.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_3.to_csv('set7_3.csv')
plot7_3 = pd.read_csv('set7_3.csv')

new7_4 = services.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_4.to_csv('set7_4.csv')
plot7_4 = pd.read_csv('set7_4.csv')

new7_5 = property.groupby(['Year,month','vertical','seller_type']).agg({'Avg_leads': pd.Series.sum})
new7_5.to_csv('set7_5.csv')
plot7_5 = pd.read_csv('set7_5.csv')

# %%
fig = px.line(plot7_1, x="Year,month", y="Avg_leads", color="seller_type",height=600,width=900, 
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="15633607-c474-4945-bf27-ad5ebc3e6806" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("15633607-c474-4945-bf27-ad5ebc3e6806")) {
#                     Plotly.newPlot(
#                         '15633607-c474-4945-bf27-ad5ebc3e6806',
# ...

# %%
fig = px.line(plot7_2, x="Year,month", y="Avg_leads", color="seller_type", height=600,width=900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4489ddcf-0b9e-4e9b-8cdf-0fa4e58f5afb" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4489ddcf-0b9e-4e9b-8cdf-0fa4e58f5afb")) {
#                     Plotly.newPlot(
#                         '4489ddcf-0b9e-4e9b-8cdf-0fa4e58f5afb',
# ...

# %%
fig = px.line(plot7_3, x="Year,month", y="Avg_leads", color="seller_type", height=600,width=900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="afed6b67-9cab-4ad5-961b-9df750102d21" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("afed6b67-9cab-4ad5-961b-9df750102d21")) {
#                     Plotly.newPlot(
#                         'afed6b67-9cab-4ad5-961b-9df750102d21',
# ...

# %%
fig = px.line(plot7_4, x="Year,month", y="Avg_leads", color="seller_type",height=600,width=900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="825cc4eb-16e9-4588-96d4-efea95e813da" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("825cc4eb-16e9-4588-96d4-efea95e813da")) {
#                     Plotly.newPlot(
#                         '825cc4eb-16e9-4588-96d4-efea95e813da',
# ...

# %%
fig = px.line(plot7_5, x="Year,month", y="Avg_leads", color="seller_type",height=600,width=900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a954e92c-da2d-465c-b1e9-e66124e7d241" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a954e92c-da2d-465c-b1e9-e66124e7d241")) {
#                     Plotly.newPlot(
#                         'a954e92c-da2d-465c-b1e9-e66124e7d241',
# ...

# %%
df7['Leads_per_ad']= (df7['sumOfLeads']/df7['ad_id'])

# %%
auto1 = df7[df7['vertical']=='Auto']
generalist1 = df7[df7['vertical']=='Generalist']
jobs1 = df7[df7['vertical']=='Jobs']
services1 = df7[df7['vertical']=='Services']
property1 = df7[df7['vertical']=='Property']

# %%
new8_1 = auto1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_1.to_csv('set8_1.csv')
plot8_1 = pd.read_csv('set8_1.csv')

new8_2 = generalist1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_2.to_csv('set8_2.csv')
plot8_2 = pd.read_csv('set8_2.csv')

new8_3 = jobs1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_3.to_csv('set8_3.csv')
plot8_3 = pd.read_csv('set8_3.csv')

new8_4 = services1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_4.to_csv('set8_4.csv')
plot8_4 = pd.read_csv('set8_4.csv')

new8_5 = property1.groupby(['Year,month','vertical','seller_type']).agg({'Leads_per_ad': pd.Series.mean})
new8_5.to_csv('set8_5.csv')
plot8_5 = pd.read_csv('set8_5.csv')

# %%
fig = px.line(plot8_1, x="Year,month", y="Leads_per_ad", color="seller_type",height=600,width=900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c379392b-ccbc-4646-b74e-1fb53b0c22b2" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c379392b-ccbc-4646-b74e-1fb53b0c22b2")) {
#                     Plotly.newPlot(
#                         'c379392b-ccbc-4646-b74e-1fb53b0c22b2',
# ...

# %%
fig = px.line(plot8_2, x="Year,month", y="Leads_per_ad", color="seller_type",height=600,width=900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="af7444d1-bf74-4c9a-83ed-612d09af74dc" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("af7444d1-bf74-4c9a-83ed-612d09af74dc")) {
#                     Plotly.newPlot(
#                         'af7444d1-bf74-4c9a-83ed-612d09af74dc',
# ...

# %%
fig = px.line(plot8_3, x="Year,month", y="Leads_per_ad", color="seller_type",height=600,width=900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="51c08d1c-f258-4f06-8e92-ad7af2751cd0" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("51c08d1c-f258-4f06-8e92-ad7af2751cd0")) {
#                     Plotly.newPlot(
#                         '51c08d1c-f258-4f06-8e92-ad7af2751cd0',
# ...

# %%
fig = px.line(plot8_4, x="Year,month", y="Leads_per_ad", color="seller_type",height=600,width=900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9056e67d-0bcb-40bc-9b25-ed76ad0bde6a" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9056e67d-0bcb-40bc-9b25-ed76ad0bde6a")) {
#                     Plotly.newPlot(
#                         '9056e67d-0bcb-40bc-9b25-ed76ad0bde6a',
# ...

# %%
fig = px.line(plot8_5, x="Year,month", y="Leads_per_ad", color="seller_type",height=600,width=900,
              line_group="seller_type", hover_name="seller_type")
fig.update_traces(mode='markers+lines')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3d7da9ec-2a2f-4ca2-9ac7-b67ba46f8af3" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3d7da9ec-2a2f-4ca2-9ac7-b67ba46f8af3")) {
#                     Plotly.newPlot(
#                         '3d7da9ec-2a2f-4ca2-9ac7-b67ba46f8af3',
# ...

# %%
df8['Avg_leads'] = (df8['sumOfLeads']/df8['days_month'])

# %%
new9 = df8.groupby(['Year,month','vertical']).agg({'Avg_leads': pd.Series.sum})
new9.to_csv('set9.csv')
plot9 = pd.read_csv('set9.csv')

# %%
auto2 = df8[df8['vertical']=='Auto']
generalist2 = df8[df8['vertical']=='Generalist']
jobs2 = df8[df8['vertical']=='Jobs']
services2 = df8[df8['vertical']=='Services']
property2 = df8[df8['vertical']=='Property']

# %%
new9_1 = auto2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_1.to_csv('set9_1.csv')
plot9_1 = pd.read_csv('set9_1.csv')

new9_2 = generalist2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_2.to_csv('set9_2.csv')
plot9_2 = pd.read_csv('set9_2.csv')

new9_3 = jobs2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_3.to_csv('set9_3.csv')
plot9_3 = pd.read_csv('set9_3.csv')

new9_4 = services2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_4.to_csv('set9_4.csv')
plot9_4 = pd.read_csv('set9_4.csv')

new9_5 = property2.groupby(['Year,month','reply_type']).agg({'Avg_leads': pd.Series.sum})
new9_5.to_csv('set9_5.csv')
plot9_5 = pd.read_csv('set9_5.csv')

# %%
fig = px.bar(plot9_1, x="Year,month", y="Avg_leads", color="reply_type",color_discrete_sequence=px.colors.qualitative.Dark24,height=600,width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f7e729e1-8f3b-4b47-b4d0-a4a42818effc" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f7e729e1-8f3b-4b47-b4d0-a4a42818effc")) {
#                     Plotly.newPlot(
#                         'f7e729e1-8f3b-4b47-b4d0-a4a42818effc',
# ...

# %%
fig = px.bar(plot9_2, x="Year,month", y="Avg_leads", color="reply_type",color_discrete_sequence=px.colors.qualitative.Dark24,height=600,width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="908cb2a8-81c3-4815-ab16-2496e9e35f27" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("908cb2a8-81c3-4815-ab16-2496e9e35f27")) {
#                     Plotly.newPlot(
#                         '908cb2a8-81c3-4815-ab16-2496e9e35f27',
# ...

# %%
fig = px.bar(plot9_3, x="Year,month", y="Avg_leads", color="reply_type",color_discrete_sequence=px.colors.qualitative.Dark24,height=600,width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="701b843e-7353-4a9d-8ae3-99df7b25960e" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("701b843e-7353-4a9d-8ae3-99df7b25960e")) {
#                     Plotly.newPlot(
#                         '701b843e-7353-4a9d-8ae3-99df7b25960e',
# ...

# %%
fig = px.bar(plot9_4, x="Year,month", y="Avg_leads", color="reply_type",color_discrete_sequence=px.colors.qualitative.Dark24,height=600,width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c628ac37-2cf3-4219-bcf2-8b0010395fe7" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c628ac37-2cf3-4219-bcf2-8b0010395fe7")) {
#                     Plotly.newPlot(
#                         'c628ac37-2cf3-4219-bcf2-8b0010395fe7',
# ...

# %%
fig = px.bar(plot9_5, x="Year,month", y="Avg_leads", color="reply_type",color_discrete_sequence=px.colors.qualitative.Dark24,height=600,width=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="106f27db-f9e6-4e2c-b14d-5bbfa8e64de3" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("106f27db-f9e6-4e2c-b14d-5bbfa8e64de3")) {
#                     Plotly.newPlot(
#                         '106f27db-f9e6-4e2c-b14d-5bbfa8e64de3',
# ...

# %%
df9['Avg_leads'] = (df9['sumOfLeads']/df9['days_month'])

# %%
new10 = df9.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10.to_csv('set10.csv')
plot10 = pd.read_csv('set10.csv')

# %%
apart = df9[df9['subcategory']=='Apartments']
car = df9[df9['subcategory']=='Cars']
house = df9[df9['subcategory']=='Houses']

text = df9[df9['subcategory']=='Textbooks']
tick = df9[df9['subcategory']=='Tickets & Vouchers']
wedd = df9[df9['subcategory']=='Wedding']

# %%
new10_1 = apart.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_1.to_csv('set10_1.csv')
plot10_1 = pd.read_csv('set10_1.csv')

new10_2 = car.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_2.to_csv('set10_2.csv')
plot10_2 = pd.read_csv('set10_2.csv')

new10_3 = house.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_3.to_csv('set10_3.csv')
plot10_3 = pd.read_csv('set10_3.csv')

new10_4 = text.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_4.to_csv('set10_4.csv')
plot10_4 = pd.read_csv('set10_4.csv')

new10_5 = tick.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_5.to_csv('set10_5.csv')
plot10_5 = pd.read_csv('set10_5.csv')

new10_6 = wedd.groupby(['Year,month','subcategory']).agg({'Avg_leads': pd.Series.sum})
new10_6.to_csv('set10_6.csv')
plot10_6 = pd.read_csv('set10_6.csv')

# %%
import plotly.express as px
subcategory = plot10['subcategory']
labels=subcategory[:43]
for category in subcategory[:43]:
    df_b=plot10[plot10['subcategory']==category]    
    fig=px.line(df_b, x="Year,month", y="Avg_leads",labels="subcategory",height=600,width=900) 
    print(category) 
    fig.update_traces(mode='markers+lines')   
    fig.show()
# Out:
# Accessories for Phones & Gadgets
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e6fb3888-39f4-4b38-b925-8bf9e7156519" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e6fb3888-39f4-4b38-b925-8bf9e7156519")) {
#                     Plotly.newPlot(
#                         'e6fb3888-39f4-4b38-b925-8bf9e7156519',
# ...

# %%
df10['Leads_per_ad']= (df10['sumOfLeads']/df10['ad_id'])

# %%
new11 = df10.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11.to_csv('set11.csv')
plot11 = pd.read_csv('set11.csv')

# %%
apart1 = df10[df10['subcategory']=='Apartments']
car1 = df10[df10['subcategory']=='Cars']
house1 = df10[df10['subcategory']=='Houses']

text1 = df10[df10['subcategory']=='Textbooks']
tick1 = df10[df10['subcategory']=='Tickets & Vouchers']
wedd1 = df10[df10['subcategory']=='Wedding']

# %%
new11_1 = apart1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_1.to_csv('set11_1.csv')
plot11_1 = pd.read_csv('set11_1.csv')

new11_2 = car1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_2.to_csv('set11_2.csv')
plot11_2 = pd.read_csv('set11_2.csv')

new11_3 = house1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_3.to_csv('set11_3.csv')
plot11_3 = pd.read_csv('set11_3.csv')

new11_4 = text1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_4.to_csv('set11_4.csv')
plot11_4 = pd.read_csv('set11_4.csv')

new11_5 = tick1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_5.to_csv('set11_5.csv')
plot11_5 = pd.read_csv('set11_5.csv')

new11_6 = wedd1.groupby(['Year,month','subcategory']).agg({'Leads_per_ad': pd.Series.mean})
new11_6.to_csv('set11_6.csv')
plot11_6 = pd.read_csv('set11_6.csv')

# %%
subcategory = plot11['subcategory']
labels=subcategory[:43]
for category in subcategory[:43]:
    df_b1=plot11[plot11['subcategory']==category]    
    fig=px.line(df_b1, x="Year,month", y="Leads_per_ad",labels="subcategory",color_discrete_sequence=['red'],height=600,width=900) 
    print(category) 
    fig.update_traces(mode='markers+lines')   
    fig.show()
# Out:
# Accessories for Phones & Gadgets
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f7979e0f-9098-4f48-9fc6-050306b08f28" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f7979e0f-9098-4f48-9fc6-050306b08f28")) {
#                     Plotly.newPlot(
#                         'f7979e0f-9098-4f48-9fc6-050306b08f28',
# ...

# %%
df11['Avg_leads'] = (df11['sumOfLeads']/df11['days_month'])

# %%
new12 = df11.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12.to_csv('set12.csv')
plot12 = pd.read_csv('set12.csv')

# %%
kl = df11[df11['region']=='Kuala Lumpur']
slg = df11[df11['region']=='Selangor']
jhr = df11[df11['region']=='Johor']

lab = df11[df11['region']=='Labuan']
per = df11[df11['region']=='Perlis']
put = df11[df11['region']=='Putrajaya']

# %%
new12_1 = kl.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_1.to_csv('set12_1.csv')
plot12_1 = pd.read_csv('set12_1.csv')

new12_2 = slg.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_2.to_csv('set12_2.csv')
plot12_2 = pd.read_csv('set12_2.csv')

new12_3 = jhr.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_3.to_csv('set12_3.csv')
plot12_3 = pd.read_csv('set12_3.csv')

new12_4 = lab.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_4.to_csv('set12_4.csv')
plot12_4 = pd.read_csv('set12_4.csv')

new12_5 = per.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_5.to_csv('set12_5.csv')
plot12_5 = pd.read_csv('set12_5.csv')

new12_6 = put.groupby(['Year,month','region']).agg({'Avg_leads': pd.Series.sum})
new12_6.to_csv('set12_6.csv')
plot12_6 = pd.read_csv('set12_6.csv')

# %%
region = plot12['region']
labels=region[:16]
for regions in region[:16]:
    df_b2=plot12[plot12['region']==regions]    
    fig=px.line(df_b2, x="Year,month", y="Avg_leads",labels="region",color_discrete_sequence=['green'],height=600,width=900) 
    print(regions)
    fig.update_traces(mode='markers+lines')
    
    fig.show()
# Out:
# Johor
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ece93d64-c287-43cc-8db0-3531886f9e87" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ece93d64-c287-43cc-8db0-3531886f9e87")) {
#                     Plotly.newPlot(
#                         'ece93d64-c287-43cc-8db0-3531886f9e87',
# ...

# %%
df12['Leads_per_ad']=(df12['sumOfLeads']/df12['ad_id'])

# %%
new13 = df12.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13.to_csv('set13.csv')
plot13 = pd.read_csv('set13.csv')

# %%
kl1 = df12[df12['region']=='Kuala Lumpur']
slg1 = df12[df12['region']=='Selangor']
jhr1 = df12[df12['region']=='Johor']

lab1 = df12[df12['region']=='Labuan']
per1 = df12[df12['region']=='Perlis']
put1 = df12[df12['region']=='Putrajaya']

# %%
new13_1 = kl1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_1.to_csv('set13_1.csv')
plot13_1 = pd.read_csv('set13_1.csv')

new13_2 = slg1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_2.to_csv('set13_2.csv')
plot13_2 = pd.read_csv('set13_2.csv')

new13_3 = jhr1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_3.to_csv('set13_3.csv')
plot13_3 = pd.read_csv('set13_3.csv')

new13_4 = lab1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_4.to_csv('set13_4.csv')
plot13_4 = pd.read_csv('set13_4.csv')

new13_5 = per1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_5.to_csv('set13_5.csv')
plot13_5 = pd.read_csv('set13_5.csv')

new13_6 = put1.groupby(['Year,month','region']).agg({'Leads_per_ad': pd.Series.mean})
new13_6.to_csv('set13_6.csv')
plot13_6 = pd.read_csv('set13_6.csv')

# %%
region = plot13['region']
labels=region[:16]
for regions in region[:16]:
    df_b3=plot13[plot13['region']==regions]    
    fig=px.line(df_b3, x="Year,month", y="Leads_per_ad",labels="region",color_discrete_sequence=['purple'],height=600,width=900) 
    print(regions)
    fig.update_traces(mode='markers+lines')    
    fig.show()
# Out:
# Johor
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3bf857b4-a10d-4563-8dc9-d829a8d9bf87" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3bf857b4-a10d-4563-8dc9-d829a8d9bf87")) {
#                     Plotly.newPlot(
#                         '3bf857b4-a10d-4563-8dc9-d829a8d9bf87',
# ...

# %%
# new141 = df13.groupby([ 'platform','operating_system']).agg({'counts': pd.Series.sum})
# new14 = df13.groupby([ 'platform']).agg({'counts': pd.Series.sum})
# new141
# new14

# %%
df3_0.groupby(['year']).agg({'sumOfLeads': pd.Series.mean})
# Out:
#         sumOfLeads
# year
# 2019  36895.669864
# 2020  28929.617374
# 2021  31578.143628
